# %%
# Packages installation.
# !pip install deepface firebase-admin Pillow tensorflow==2.15.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: deepface in ./.local/lib/python3.9/site-packages (0.0.85)
# Requirement already satisfied: firebase-admin in ./.local/lib/python3.9/site-packages (6.4.0)
# Requirement already satisfied: Pillow in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (10.0.1)
# Requirement already satisfied: tensorflow==2.15.0 in ./.local/lib/python3.9/site-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from tensorflow==2.15.0) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (3.3.0)
# Requirement already satisfied: packaging in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from tensorflow==2.15.0) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (4.25.3)
# Requirement already satisfied: setuptools in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from tensorflow==2.15.0) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from tensorflow==2.15.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from tensorflow==2.15.0) (4.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (1.62.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in ./.local/lib/python3.9/site-packages (from tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: pandas>=0.23.4 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from deepface) (2.1.3)
# Requirement already satisfied: gdown>=3.10.1 in ./.local/lib/python3.9/site-packages (from deepface) (5.1.0)
# Requirement already satisfied: tqdm>=4.30.0 in ./.local/lib/python3.9/site-packages (from deepface) (4.66.2)
# Requirement already satisfied: opencv-python>=4.5.5.64 in ./.local/lib/python3.9/site-packages (from deepface) (4.9.0.80)
# Requirement already satisfied: Flask>=1.1.2 in ./.local/lib/python3.9/site-packages (from deepface) (3.0.2)
# Requirement already satisfied: mtcnn>=0.1.0 in ./.local/lib/python3.9/site-packages (from deepface) (0.1.1)
# Requirement already satisfied: retina-face>=0.0.1 in ./.local/lib/python3.9/site-packages (from deepface) (0.0.14)
# Requirement already satisfied: fire>=0.4.0 in ./.local/lib/python3.9/site-packages (from deepface) (0.5.0)
# Requirement already satisfied: gunicorn>=20.1.0 in ./.local/lib/python3.9/site-packages (from deepface) (21.2.0)
# Requirement already satisfied: cachecontrol>=0.12.6 in ./.local/lib/python3.9/site-packages (from firebase-admin) (0.14.0)
# Requirement already satisfied: google-api-python-client>=1.7.8 in ./.local/lib/python3.9/site-packages (from firebase-admin) (2.121.0)
# Requirement already satisfied: google-cloud-storage>=1.37.1 in ./.local/lib/python3.9/site-packages (from firebase-admin) (2.15.0)
# Requirement already satisfied: pyjwt>=2.5.0 in ./.local/lib/python3.9/site-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (2.8.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.22.1 in ./.local/lib/python3.9/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.17.1)
# Requirement already satisfied: google-cloud-firestore>=2.9.1 in ./.local/lib/python3.9/site-packages (from firebase-admin) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow==2.15.0) (0.41.2)
# Requirement already satisfied: requests>=2.16.0 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from cachecontrol>=0.12.6->firebase-admin) (2.31.0)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in ./.local/lib/python3.9/site-packages (from cachecontrol>=0.12.6->firebase-admin) (1.0.8)
# Requirement already satisfied: Werkzeug>=3.0.0 in ./.local/lib/python3.9/site-packages (from Flask>=1.1.2->deepface) (3.0.1)
# Requirement already satisfied: Jinja2>=3.1.2 in ./.local/lib/python3.9/site-packages (from Flask>=1.1.2->deepface) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in ./.local/lib/python3.9/site-packages (from Flask>=1.1.2->deepface) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in ./.local/lib/python3.9/site-packages (from Flask>=1.1.2->deepface) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in ./.local/lib/python3.9/site-packages (from Flask>=1.1.2->deepface) (1.7.0)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from Flask>=1.1.2->deepface) (7.0.1)
# Requirement already satisfied: beautifulsoup4 in ./.local/lib/python3.9/site-packages (from gdown>=3.10.1->deepface) (4.12.3)
# Requirement already satisfied: filelock in ./.local/lib/python3.9/site-packages (from gdown>=3.10.1->deepface) (3.13.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./.local/lib/python3.9/site-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.62.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in ./.local/lib/python3.9/site-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.28.2)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in ./.local/lib/python3.9/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.62.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in ./.local/lib/python3.9/site-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.22.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in ./.local/lib/python3.9/site-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in ./.local/lib/python3.9/site-packages (from google-api-python-client>=1.7.8->firebase-admin) (4.1.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in ./.local/lib/python3.9/site-packages (from google-cloud-firestore>=2.9.1->firebase-admin) (2.4.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in ./.local/lib/python3.9/site-packages (from google-cloud-firestore>=2.9.1->firebase-admin) (1.23.0)
# Requirement already satisfied: google-resumable-media>=2.6.0 in ./.local/lib/python3.9/site-packages (from google-cloud-storage>=1.37.1->firebase-admin) (2.7.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in ./.local/lib/python3.9/site-packages (from google-cloud-storage>=1.37.1->firebase-admin) (1.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from pandas>=0.23.4->deepface) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from pandas>=0.23.4->deepface) (2023.3)
# Requirement already satisfied: cryptography>=3.4.0 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (41.0.4)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./.local/lib/python3.9/site-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in ./.local/lib/python3.9/site-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.local/lib/python3.9/site-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: cffi>=1.12 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.local/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.local/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.local/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.local/lib/python3.9/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.3.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client>=1.7.8->firebase-admin) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from importlib-metadata>=3.6.0->Flask>=1.1.2->deepface) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.local/lib/python3.9/site-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in ./.local/lib/python3.9/site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: pycparser in /glob/development-tools/versions/oneapi/2024.0.2.1/oneapi/intelpython/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (2.21)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.local/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.local/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.2.2)

# %%
# Importing section
import os
from deepface import DeepFace
import firebase_admin

from firebase_admin import credentials, storage

# %%
# Load Firebase credentials and initialize the app with storage configuration
def initialize_firebase():
    if not firebase_admin._apps:
        cred = credentials.Certificate('auth.json')
        firebase_admin.initialize_app(cred, {'storageBucket': 'coldrecog.appspot.com'})
    return storage.bucket()

# %%
# Function to compare images and return the minimum match rate and corresponding file path
def compare_images(test_img_path, folder_path):
    # Access the default Cloud Storage bucket
    bucket = initialize_firebase()
    
    # List all the blobs (files) in the specified folder path
    blobs = bucket.list_blobs(prefix=folder_path)
    
    # Temporary file path for storing the downloaded reference image
    reference_img_path = "temp.jpg"
    
    # Dictionary to store the match rates for each image
    predict = {}

    # Loop through each blob in the specified folder
    for blob in blobs:
        try:
            # Get the file path of the current blob
            file_path = blob.name
            
            # Skip if the file path corresponds to the folder itself
            if file_path == folder_path + '/':
                continue
            
            # Download the image data from the current blob
            blob = bucket.blob(file_path)
            image_data = blob.download_as_bytes()

            # Save the downloaded image locally
            local_file_path = f'./{reference_img_path}'
            with open(local_file_path, 'wb') as local_file:
                local_file.write(image_data)

            # Use DeepFace library to verify similarity between reference and test images
            result = DeepFace.verify(reference_img_path, test_img_path)
            match_rate = round(result["distance"] * 100, 2)

            # Store the match rate in the dictionary with the file path as the key
            predict[file_path] = match_rate
            
            # Remove the temporary reference image file
            os.remove(reference_img_path)

        except Exception as e:
            print(file_path)
            print(f'Error: {e}')
            print("Loading.....")

    # Find the minimum match rate and corresponding file path(s)
    matched = min(predict.values())
    res = [key for key in predict if predict[key] == matched]
    return res[0], matched

# %%
# Define the folder path in the bucket
print("Processing...")
folder_path = 'aadhar'  # Replace with the correct folder path

# Get the test image path from the user
test_img_path = "test.png"

# Call the function to compare images and get the result
# %time matched_file, match_distance = compare_images(test_img_path, folder_path)
print("The Match is", matched_file, "with distance of", match_distance)
# Out:
# Processing...
# CPU times: user 1min 56s, sys: 8.01 s, total: 2min 4s
# Wall time: 1min 16s
# The Match is aadhar/2.png with distance of 53.71
